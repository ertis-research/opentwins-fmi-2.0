# %%
from fmpy import *
from zipfile import ZipFile
import pandas as pd

# %%
result = simulate_fmu("FMUs/bouncingBallCS2.fmu", start_time= 0, stop_time=5)

header = list(result.dtype.names)

results_df = pd.DataFrame(result, columns=header)
# result = simulate_fmu(filename="FMUs/bouncingBallCS2.fmu", start_time= 4, stop_time=5)
# plot_result(result)

# %%
print(results_df)
