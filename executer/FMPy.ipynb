# %%
from fmpy import *
from fmpy import 
from zipfile import ZipFile

# %%
result = simulate_fmu("FMUs/bouncingBallCS2.fmu", start_time= 0, stop_time=5, start_values={"h":10})
plot_result(result)
# result = simulate_fmu(filename="FMUs/bouncingBallCS2.fmu", start_time= 4, stop_time=5)
# plot_result(result)

# %%
switch(){
    
}
