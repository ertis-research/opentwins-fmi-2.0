# %%
from fmpy import *
from zipfile import ZipFile

# %%
with ZipFile("FMUs/bouncingBallCS2.fmu", 'r') as fmu:

    result = simulate_fmu(fmu, start_time= 0, stop_time=5)
    plot_result(result)
# result = simulate_fmu(filename="FMUs/bouncingBallCS2.fmu", start_time= 4, stop_time=5)
# plot_result(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 with ZipFile("FMUs/bouncingBallCS2.fmu", 'r') as fmu:
# ----> 3     result = simulate_fmu(fmu, start_time= 0, stop_time=5)
#       4     plot_result(result)
#       5 # result = simulate_fmu(filename="FMUs/bouncingBallCS2.fmu", start_time= 4, stop_time=5)
#       6 # plot_result(result)
#
# ...
